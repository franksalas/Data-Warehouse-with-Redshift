# %% [markdown]
# # Load Libraries

# %%
# %load_ext sql
import configparser
import psycopg2
import pandas as pd

# %% [markdown]
# ## Load params from file

# %%
config = configparser.ConfigParser()
config.read_file(open('dwh.cfg'))

DWH_CLUSTER_TYPE       = config.get("DWH","DWH_CLUSTER_TYPE")
DWH_NUM_NODES          = config.get("DWH","DWH_NUM_NODES")
DWH_NODE_TYPE          = config.get("DWH","DWH_NODE_TYPE")

DWH_CLUSTER_IDENTIFIER = config.get("DWH","DWH_CLUSTER_IDENTIFIER")
DWH_DB                 = config.get("DWH","DWH_DB")
DWH_DB_USER            = config.get("DWH","DWH_DB_USER")
DWH_DB_PASSWORD        = config.get("DWH","DWH_DB_PASSWORD")
DWH_PORT               = config.get("DWH","DWH_PORT")

DWH_IAM_ROLE_NAME      = config.get("DWH", "DWH_IAM_ROLE_NAME")

# %%
DWH_ENDPOINT ='dwhcluster.ctkgati4b0qj.us-west-2.redshift.amazonaws.com'

# %% [markdown]
# ## Connect

# %%
conn_string="postgresql://{}:{}@{}:{}/{}".format(DWH_DB_USER, DWH_DB_PASSWORD, DWH_ENDPOINT, DWH_PORT,DWH_DB)
# %sql $conn_string
# Out:
# 'Connected: dwhuser@dwh'

# %% [markdown]
# # STAGING TABLES

# %%
# %%sql
# SELECT
#     *
# FROM
#     staging_events
# LIMIT
#     10
# Out:
#  * postgresql://dwhuser:***@dwhcluster.ctkgati4b0qj.us-west-2.redshift.amazonaws.com:5439/dwh
# 10 rows affected.
# [('The Backyardigans', 'Logged In', 'Aleena', 'F', 4, 'Kirby', Decimal('158.85015'), 'paid', 'Waterloo-Cedar Falls, IA', 'PUT', 'NextSong', 1541022995796, 237, 'Into The Thick Of It!', 200, datetime.datetime(2018, 11, 5, 1, 42, 0, 796000), 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0', 44),
#  ('Ron Carter', 'Logged In', 'Aleena', 'F', 12, 'Kirby', Decimal('497.13587'), 'paid', 'Waterloo-Cedar Falls, IA', 'PUT', 'NextSong', 1541022995796, 237, "I CAN'T GET STARTED", 200, datetime.datetime(2018, 11, 5, 2, 9, 47, 796000), 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0', 44),
#  ('Kings Of Leon', 'Logged In', 'Aleena', 'F', 20, 'Kirby', Decimal('201.79545'), 'paid', 'Waterloo-Cedar Falls, IA', 'PUT', 'NextSong', 1541022995796, 237, 'Revelry', 200, datetime.datetime(2018, 11, 5, 2, 45, 11, 796000), 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0', 44),
#  ('The Killers', 'Logged In', 'Lily', 'F', 0, 'Burns', Decimal('185.33832'), 'free', 'New York-Newark-Jersey City, NY-NJ-PA', 'PUT', 'NextSong', 1540621059796, 239, "I Can't Stay", 200, datetime.datetime(2018, 11, 5, 4, 44, 14, 796000), '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', 32),
#  ('Arctic Monkeys', 'Logged In', 'Katherine', 'F', 3, 'Gay', Decimal('177.94567'), 'free', 'San Antonio-New Braunfels, TX', 'PUT', 'NextSong', 1540968306796, 56, 'Fake Tales Of San Francisco', 200, datetime.datetime(2018, 11, 5, 5, 57, 5, 796000), '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8) AppleWebKit/534.59.10 (KHTML, like Gecko) Version/5.1.9 Safari/534.59.10"', 57),
#  ('Powderfinger', 'Logged In', 'Harper', 'M', 0, 'Barrett', Decimal('276.68853'), 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', 'PUT', 'NextSong', 1540685364796, 129, 'My Happiness', 200, datetime.datetime(2018, 11, 5, 8, 42, 46, 796000), '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', 42),
#  ('Chaka Khan', 'Logged In', 'Harper', 'M', 7, 'Barrett', Decimal('280.86811'), 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', 'PUT', 'NextSong', 1540685364796, 129, "Ain't Nobody (Album Version)", 200, datetime.datetime(2018, 11, 5, 9, 4, 22, 796000), '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', 42),
#  ('Martin Gore', 'Logged In', 'Sara', 'F', 0, 'Johnson', Decimal('241.10974'), 'paid', 'Winston-Salem, NC', 'PUT', 'NextSong', 1540809153796, 222, 'By This River', 200, datetime.datetime(2018, 11, 5, 9, 26, 30, 796000), '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', 95),
#  ('Nino Bravo', 'Logged In', 'Sara', 'F', 3, 'Johnson', Decimal('218.48770'), 'paid', 'Winston-Salem, NC', 'PUT', 'NextSong', 1540809153796, 222, 'Amanecer', 200, datetime.datetime(2018, 11, 5, 9, 39, 42, 796000), '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', 95),
#  ('Nancy Wilson', 'Logged In', 'Harper', 'M', 20, 'Barrett', Decimal('122.77506'), 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', 'PUT', 'NextSong', 1540685364796, 129, 'I Believe In You', 200, datetime.datetime(2018, 11, 5, 9, 52, 41, 796000), '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', 42)]

# %%
# %%sql
# SELECT
#     *
# FROM
#     staging_songs
# LIMIT
#     10
# Out:
#  * postgresql://dwhuser:***@dwhcluster.ctkgati4b0qj.us-west-2.redshift.amazonaws.com:5439/dwh
# 10 rows affected.
# [(1, 'ARNUJQM1187FB3EE72', None, None, 'Bergen County, NJ', 'Number Twelve Looks Like You', 'SOBIODA12A8C13CDAD', 'Cradle the Crater', Decimal('258.29831'), 2007),
#  (1, 'AR5R1EG1187FB3E94F', Decimal('46.35316'), Decimal('-94.20068'), 'Brainerd, MN', 'Linda Eder', 'SORLOYR12AB0188AAC', 'On The Street Where You Live (album version)', Decimal('205.11302'), 2003),
#  (1, 'ARVZDOM1187B9B49C9', None, None, 'Brooklyn, NY', 'Barry Manilow', 'SOEGWEI12A8C143182', 'Some Bar By The Harbor', Decimal('298.99709'), 0),
#  (1, 'ARIOSKN1257509BCE1', None, None, None, 'Cama', 'SOBUWPY12A8C1446C0', 'In This Life', Decimal('210.36363'), 2009),
#  (1, 'AR470HW1187FB3B8DF', None, None, 'Bakersfield, CA', 'Merle Haggard And The Strangers', 'SOTTXMZ12A6D4F6DB1', 'Folsom Prison Blues', Decimal('165.69424'), 2006),
#  (1, 'ARIRDVY1187FB587CC', Decimal('-33.86963'), Decimal('151.20695'), 'Sydney, New South Wales, Australi', 'The Beautiful Girls', 'SOBZHTP12A8C13B9B7', 'Shot Down', Decimal('404.08771'), 2005),
#  (1, 'ARFI49X1187FB473D0', None, None, None, 'David Kitt', 'SOZXNGX12A8C13FBD4', 'Up To You', Decimal('224.57424'), 2006),
#  (1, 'ARM8Y3L1187FB537A7', None, None, None, 'Mortal', 'SOHWKNM12A8C135A07', 'Word Is Alive_ The (Jeromix)  (Mortal Album Version)', Decimal('290.55955'), 0),
#  (1, 'ARAXZGI1187FB3EB5F', None, None, None, 'Ana Carolina', 'SOHRARU12AC468E3DD', 'É Hora Da Virada', Decimal('188.39465'), 2003),
#  (1, 'ARZ9FGC1187B98B47D', None, None, 'St. Albans, Herts, England', 'The Zombies', 'SOUTFFK12AB0184613', 'I Know She Will', Decimal('152.84200'), 1974)]

# %% [markdown]
# ## USERS TABLE

# %%
# %%sql
# SELECT
#     *
# FROM
#     users
# LIMIT
#     10
# Out:
#  * postgresql://dwhuser:***@dwhcluster.ctkgati4b0qj.us-west-2.redshift.amazonaws.com:5439/dwh
# 10 rows affected.
# [(2, 'Jizelle', 'Benjamin', 'F', 'free'),
#  (9, 'Wyatt', 'Scott', 'M', 'free'),
#  (40, 'Tucker', 'Garrison', 'M', 'free'),
#  (54, 'Kaleb', 'Cook', 'M', 'free'),
#  (57, 'Katherine', 'Gay', 'F', 'free'),
#  (59, 'Lily', 'Cooper', 'F', 'free'),
#  (63, 'Ayla', 'Johnson', 'F', 'free'),
#  (67, 'Colm', 'Santana', 'M', 'free'),
#  (73, 'Jacob', 'Klein', 'M', 'paid'),
#  (95, 'Sara', 'Johnson', 'F', 'paid')]

# %% [markdown]
# ## SONG TABLE

# %%
# %%sql
# SELECT
#     *
# FROM
#     songs
# LIMIT
#     10
# Out:
#  * postgresql://dwhuser:***@dwhcluster.ctkgati4b0qj.us-west-2.redshift.amazonaws.com:5439/dwh
# 10 rows affected.
# [('SOABNBI12A8C13F890', 'Mon légionaire', 'AR5O86P1187FB3B8CD', 0, Decimal('216.86812')),
#  ('SOABNPW12A6D4FC9B5', 'The Canals Of Our City', 'ARQOBT71187FB4CCCA', 2005, Decimal('141.11302')),
#  ('SOABQFG12A58A7C6A7', 'Seven Samurai - ending theme', 'ARKZESI119B86682ED', 0, Decimal('340.84526')),
#  ('SOABVPU12AB018AA22', 'Conquer Me', 'ARZZRK91187B9A5CA5', 2009, Decimal('180.53179')),
#  ('SOABWGO12AB0182725', "I'm Just A Prisoner", 'ARCCX2V1187B99DEE6', 1976, Decimal('192.88771')),
#  ('SOABZNS12A6D4F9B39', 'Epoque Scolaire (Interlude)', 'ARZO9UQ1187FB4D261', 1999, Decimal('89.18159')),
#  ('SOACAKP12AB018638D', 'Faut que tu fesses fort', 'ARZORKK11E2835CDA4', 1999, Decimal('137.92608')),
#  ('SOADMFM12A8C131911', 'Hard As Steel', 'AR3K1T51187FB4042A', 0, Decimal('309.47219')),
#  ('SOADVER12A6D4F68AF', 'Love Her With A Feeling', 'ARRT66G1187FB3DDF9', 1991, Decimal('301.71382')),
#  ('SOAEIOI12A8C142037', 'Daydream Romance (Album Version)', 'AR2GNDZ1187FB3D701', 0, Decimal('216.81586'))]

# %% [markdown]
# ## ARTISTS TABLE

# %%
# %%sql
# SELECT
#     *
# FROM
#     artists
# LIMIT
#     10
# Out:
#  * postgresql://dwhuser:***@dwhcluster.ctkgati4b0qj.us-west-2.redshift.amazonaws.com:5439/dwh
# 10 rows affected.
# [('AR00FVC1187FB5BE3E', 'Panda', 'Monterrey, NL, México', Decimal('25.67083'), Decimal('-100.30953')),
#  ('AR00JIO1187B9A5A15', 'Saigon', 'Brooklyn', Decimal('40.65507'), Decimal('-73.94888')),
#  ('AR00TGQ1187B994F29', 'Paula Toller', None, None, None),
#  ('AR00Y9I1187B999412', 'Akercocke', None, None, None),
#  ('AR026BB1187B994DC3', 'Ijahman Levi', None, None, None),
#  ('AR04BF811A348F050D', 'Teenagers In Tokyo', None, None, None),
#  ('AR04KY61187FB44E3A', 'Fidel Nadal', None, None, None),
#  ('AR05TTS11C8A422FEC', 'Westbam And The Love Committee', None, None, None),
#  ('AR06ZYM1187B992A34', 'Lowgold', 'London, England', Decimal('51.50632'), Decimal('-0.12714')),
#  ('AR0709B1187B9A8E99', 'Amp Fiddler', 'Detroit', None, None)]

# %% [markdown]
# ## TIME TABLE

# %%
# %%sql
# SELECT
#     *
# FROM
#     time
# LIMIT
#     10
# Out:
#  * postgresql://dwhuser:***@dwhcluster.ctkgati4b0qj.us-west-2.redshift.amazonaws.com:5439/dwh
# 10 rows affected.
# [(datetime.datetime(2018, 11, 1, 21, 17, 33, 796000), 21, 1, 44, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 2, 3, 5, 57, 796000), 3, 2, 44, 11, 2018, 5),
#  (datetime.datetime(2018, 11, 2, 9, 8, 18, 796000), 9, 2, 44, 11, 2018, 5),
#  (datetime.datetime(2018, 11, 2, 10, 4, 5, 796000), 10, 2, 44, 11, 2018, 5),
#  (datetime.datetime(2018, 11, 2, 10, 29, 6, 796000), 10, 2, 44, 11, 2018, 5),
#  (datetime.datetime(2018, 11, 2, 11, 24, 10, 796000), 11, 2, 44, 11, 2018, 5),
#  (datetime.datetime(2018, 11, 2, 11, 34, 46, 796000), 11, 2, 44, 11, 2018, 5),
#  (datetime.datetime(2018, 11, 2, 11, 48, 19, 796000), 11, 2, 44, 11, 2018, 5),
#  (datetime.datetime(2018, 11, 2, 11, 56, 43, 796000), 11, 2, 44, 11, 2018, 5),
#  (datetime.datetime(2018, 11, 2, 12, 3, 7, 796000), 12, 2, 44, 11, 2018, 5)]

# %% [markdown]
# ## SONGPLAYS TABLE

# %%
# %%sql
# SELECT
#     *
# FROM
#     SONGPLAYS
# LIMIT
#     10
# Out:
#  * postgresql://dwhuser:***@dwhcluster.ctkgati4b0qj.us-west-2.redshift.amazonaws.com:5439/dwh
# 10 rows affected.
# [(292, datetime.datetime(2018, 11, 2, 17, 31, 45, 796000), 10, 'free', 'SOHTKMO12AB01843B0', 'AR5EYTL1187B98EDA0', 182, 'Washington-Arlington-Alexandria, DC-VA-MD-WV', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"'),
#  (285, datetime.datetime(2018, 11, 2, 18, 2, 42, 796000), 50, 'free', 'SOBONKR12A58A7A7E0', 'AR5E44Z1187B9A1D74', 207, 'New Haven-Milford, CT', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (300, datetime.datetime(2018, 11, 3, 17, 59, 1, 796000), 15, 'paid', 'SOHTKMO12AB01843B0', 'AR5EYTL1187B98EDA0', 199, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (301, datetime.datetime(2018, 11, 4, 15, 39, 36, 796000), 78, 'free', 'SOBONKR12A58A7A7E0', 'AR5E44Z1187B9A1D74', 176, 'Indianapolis-Carmel-Anderson, IN', 'Mozilla/5.0 (Windows NT 6.1; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (437, datetime.datetime(2018, 11, 5, 11, 8, 56, 796000), 95, 'paid', 'SOQYHVZ12A6D4F93CF', 'ARRZUPG11F43A69EF7', 222, 'Winston-Salem, NC', '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"'),
#  (86, datetime.datetime(2018, 11, 5, 14, 24, 56, 796000), 44, 'paid', 'SOTETAR12AF72A5FF7', 'AROR8OB1187FB50D6A', 269, 'Waterloo-Cedar Falls, IA', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (42, datetime.datetime(2018, 11, 6, 23, 32, 39, 796000), 97, 'paid', 'SOBRFPG12A8AE4837D', 'AR1N3PB1187B9B25C1', 293, 'Lansing-East Lansing, MI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  (31, datetime.datetime(2018, 11, 7, 1, 42, 43, 796000), 8, 'free', 'SOWTZNU12AB017EADB', 'AR6NYHH1187B9BA128', 181, 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"'),
#  (477, datetime.datetime(2018, 11, 7, 5, 32, 6, 796000), 50, 'free', 'SOXQUPO12A6D4FC2B6', 'AR79C1C1187FB4C482', 313, 'New Haven-Milford, CT', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (453, datetime.datetime(2018, 11, 8, 10, 7, 12, 796000), 80, 'paid', 'SOIKPOX12A58A7BA0B', 'ARBNXYA1187FB51C50', 342, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"')]

# %% [markdown]
# ## select all the artist that are from Texas

# %%
# %%sql
# SELECT *
# FROM artists
# WHERE location LIKE '%TX%';
# Out:
#  * postgresql://dwhuser:***@dwhcluster.ctkgati4b0qj.us-west-2.redshift.amazonaws.com:5439/dwh
# 134 rows affected.
# [('AR3AY3R1187FB52CF0', 'Tracy Byrd', 'Vidor, TX', None, None),
#  ('AR6B2JS1187B99C283', 'Justin Tubb', 'San Antonio, TX', Decimal('29.42448'), Decimal('-98.49461')),
#  ('AR6IJJ41187B98C872', 'Bobby Pulido', 'Edinburg, TX', Decimal('26.30115'), Decimal('-98.16070')),
#  ('ARAZP5N1187B9B4D5D', 'Okkervil River', 'Austin, TX', None, None),
#  ('ARB60IV1187FB370FE', 'Reverend Horton Heat', 'Corpus Christi, TX', Decimal('32.77814'), Decimal('-96.79540')),
#  ('ARB60IV1187FB370FE', 'The Reverend Horton Heat', 'Corpus Christi, TX', Decimal('32.77814'), Decimal('-96.79540')),
#  ('ARBQPXY1187B98D67B', 'Kris Kristofferson', 'Brownsville, TX', Decimal('25.89958'), Decimal('-97.49553')),
#  ('ARBTQ6W1187FB38032', 'Timbuk 3', 'Austin, TX', Decimal('30.26760'), Decimal('-97.74298')),
#  ('ARHYUI71187FB48366', 'Billy Preston', 'Houston, TX', Decimal('29.76044'), Decimal('-95.36978')),
#  ('ARJHPM91187B9B86C5', 'This Will Destroy You', 'Austin TX', None, None),
#  ('ARN7POH1187B9B301E', 'Jessica Simpson featuring Lil Bow Wow', 'Dallas, TX', None, None),
#  ('ARNG1DH1187FB3AB56', 'Lefty Frizzell', 'Corsicana, TX', Decimal('32.09161'), Decimal('-96.46326')),
#  ('ARNU0OM1187FB3F14A', 'Larry Groce', 'Dallas, TX', Decimal('32.77814'), Decimal('-96.79540')),
#  ('ARNU0OM1187FB3F14A', "Larry Groce/Disneyland Children's Sing-Along Chorus", 'Dallas, TX', Decimal('32.77814'), Decimal('-96.79540')),
#  ('ARR0IFY1187FB4AA95', 'Best Fwends', 'Austin TX', None, None),
#  ('ART2R7U1187FB46D12', 'Joe Sample', 'Houston, TX', Decimal('29.76044'), Decimal('-95.36978')),
#  ('ARTMZYW1187B9A7ECB', 'Hayes Carll', 'Houston TX', None, None),
#  ('ARVT7941187B9AEB48', 'Barry White', 'Galveston, TX', Decimal('29.29533'), Decimal('-94.80786')),
#  ('ARZB3YT1187B9912DD', 'Wayman Tisdale', 'Fort Worth, TX', None, None),
#  ('AR0RCMP1187FB3F427', 'Billie Jo Spears', 'Beaumont, TX', Decimal('30.08615'), Decimal('-94.10157')),
#  ('ARC5E541187FB52F8F', 'DAN SEALS', 'McCamey, TX', Decimal('31.13545'), Decimal('-102.22414')),
#  ('ARCQMJH1187B9B53CC', 'DJ Screw_ B-Legit_ Lil Keke_ Phaz_ Duke', 'Smithville, TX', Decimal('30.00874'), Decimal('-97.16001')),
#  ('AREF8VK1187FB431A6', 'PlayRadioPlay!', 'Fort Worth (Aledo), TX', None, None),
#  ('ARFM2581187FB3BCC1', 'Buck Owens', 'Sherman, TX', Decimal('33.63604'), Decimal('-96.60916')),
#  ('ARGH53H1187B9A5511', 'Cliff Bruner', 'Houston, TX', Decimal('29.76044'), Decimal('-95.36978')),
#  ('ARHMVQB1187FB3F005', 'The Polyphonic Spree', 'Dallas, TX', None, None),
#  ('ARRTHFN11F4C83D56B', 'UGK (Underground Kingz)', 'Port Arthur, TX', Decimal('29.89931'), Decimal('-93.92937')),
#  ('ARRWSRA1187FB3AFEB', 'Sparta', 'El, Paso, TX', None, None),
#  ('ART3O5Z1187B9AB043', 'Stevie Ray Vaughan And Double Trouble', 'Dallas, TX', Decimal('32.77814'), Decimal('-96.79540')),
#  ('ARTJPA61187B9A7884', "Li'l Cap'n Travis", 'Austin TX', None, None),
#  ('ARTKQE41187FB5A378', 'The Union Underground', 'San Antonio, TX', Decimal('29.42448'), Decimal('-98.49461')),
#  ('ARWV0Q11187FB4CDCE', 'Arc Angels', 'Austin, TX', None, None),
#  ('AR3FDXK1187FB3BDAD', 'Centro-matic', 'Denton TX', None, None),
#  ('AR3Q98N1187B9B914E', 'Flaco Jimenez feat. Dwight Yoakam', 'San Antonio, TX', Decimal('29.42448'), Decimal('-98.49461')),
#  ('AR3Q98N1187B9B914E', 'Flaco Jimenez', 'San Antonio, TX', Decimal('29.42448'), Decimal('-98.49461')),
#  ('AR9MJOC1187FB3FE1B', 'Pocket Full Of Rocks', 'Texarkana, TX', Decimal('33.42557'), Decimal('-94.04824')),
#  ('ARC8CQZ1187B98DECA', 'Jack Johnson', 'Galveston, TX', None, None),
#  ('ARE36MM1187B991E50', 'Blind Lemon Jefferson', 'Couchman, TX', Decimal('31.16890'), Decimal('-100.07715')),
#  ('ARJOEGM1187B9B8F24', 'Jeannie C. Riley', 'Anson, TX', Decimal('32.75103'), Decimal('-99.89682')),
#  ('ARLNQBR1187B9B9C4D', 'Devendra Banhart', 'Houston, TX', None, None),
#  ('ARM6SZL1187FB3E800', 'Alvis Wayne', 'Puduka, TX', Decimal('31.16890'), Decimal('-100.07715')),
#  ('ARS7RD11187B9B5542', 'Eisley', 'Tyler TX', None, None),
#  ('ARSKAM81187FB44F46', 'Jackopierce', 'Dallas, TX', Decimal('32.77814'), Decimal('-96.79540')),
#  ('ARU9LLJ1187B9B8AB2', 'Ashlee Simpson', 'Waco, TX', Decimal('31.57181'), Decimal('-97.14950')),
#  ('ARW5RHX1187B9A86C8', 'Travolta', 'Austin, TX', Decimal('30.26760'), Decimal('-97.74298')),
#  ('ARYN6H41187B98AA0F', 'Michael Martin Murphey', 'Dallas, TX', Decimal('32.77814'), Decimal('-96.79540')),
#  ('ARZ5CQT1187FB4CF24', 'The American Analog Set', 'Austin, TX', Decimal('30.26760'), Decimal('-97.74298')),
#  ('ARZ5CQT1187FB4CF24', 'Steve Schneider', 'Austin, TX', Decimal('30.26760'), Decimal('-97.74298')),
#  ('ARZYRP21187FB53526', 'Bedhead', 'Dallas, TX', None, None),
#  ('AR6QCJA1187FB56BE8', 'Hank Thompson', 'Waco, TX', Decimal('31.57181'), Decimal('-97.14950')),
#  ('ARBFDJW1187B9AD27A', 'The Fabulous Thunderbirds', 'Austin, TX', Decimal('30.26760'), Decimal('-97.74298')),
#  ('ARCHCB01187B9AA577', 'Lil Flip_ DJ Double R', 'Houston, TX', None, None),
#  ('ARCHCB01187B9AA577', 'Lil Flip', 'Houston, TX', None, None),
#  ('ARDBRC81187FB49B20', 'Oh_ Sleeper', 'Fort Worth, TX', Decimal('32.74862'), Decimal('-97.32925')),
#  ('ARDZT5Q1187B9BA468', 'Red Garland', 'Dallas, TX', Decimal('32.77814'), Decimal('-96.79540')),
#  ('ARLTWXK1187FB5A3F8', 'King Curtis', 'Fort Worth, TX', Decimal('32.74862'), Decimal('-97.32925')),
#  ('ARNXNH81187FB52EB5', 'Baby Bash / Grimm', 'Houston, TX', None, None),
#  ('ARNXNH81187FB52EB5', 'Baby Bash', 'Houston, TX', None, None),
#  ('ARO4WQR1187B9B9825', 'Kenny Rogers', 'Houston, TX', None, None),
#  ('ARRTPN61187B9A3812', 'Scott Joplin', 'Bowie City, TX', Decimal('33.55942'), Decimal('-97.84834')),
#  ('ARX18RJ1187B9AEFB7', 'Absu', 'Dallas, TX', Decimal('32.77814'), Decimal('-96.79540')),
#  ('AR0SRVL1187B98A9C3', 'Mac Davis', 'Lubbock, TX', Decimal('33.59232'), Decimal('-101.85587')),
#  ('AR2UL9Z1187B9B727F', 'Mason Ruffner', 'Fort Worth, TX', Decimal('32.74862'), Decimal('-97.32925')),
#  ('AR3ZD9L1187B99EC5A', 'Golden Boys', 'Austin TX', Decimal('41.64421'), Decimal('-87.70202')),
#  ('AR5JDDD1187FB460C4', 'The Octopus Project + Black Moth Super Rainbow', 'Austin, TX', Decimal('30.26760'), Decimal('-97.74298')),
#  ('AR5JDDD1187FB460C4', 'Octopus Project', 'Austin, TX', Decimal('30.26760'), Decimal('-97.74298')),
#  ('AR8LMZM1187B9A8160', 'Brooke Valentine', 'Houston, TX', None, None),
#  ('AR9OLFX1187B9A5762', 'Bob Wills', 'Kosse, TX', Decimal('31.30756'), Decimal('-96.63165')),
#  ('AR9S5JR11C8A416119', 'Tritonal', 'Austin, TX', Decimal('30.26760'), Decimal('-97.74298')),
#  ('ARA2J4X1187B9B7FEF', 'Stephen Stills', 'Dallas, TX', Decimal('32.77814'), Decimal('-96.79540')),
#  ('ARA3YV11187B9A916A', 'Secret Machines', 'Dallas, TX', Decimal('32.77814'), Decimal('-96.79540')),
#  ('AREV0ZO1187B997221', 'Doyle Bramhall', 'Dallas, TX', Decimal('32.77814'), Decimal('-96.79540')),
#  ('ARHB1TE1187B9BA5C0', 'Fenix TX', 'Houston, TX', None, None),
#  ('ARHN74X1187B98D79F', 'Bill Engvall', 'Galveston, TX', None, None),
#  ('ARJFOC01187FB413A5', 'Delbert McClinton', 'Lubbock, TX', Decimal('33.59232'), Decimal('-101.85587')),
#  ('ARKQGYN11F4C83D508', 'Riverboat Gamblers', 'Austin TX', None, None),
#  ('ARMCPJL1187FB42407', 'Vikki Carr', 'El Paso, TX', Decimal('31.75916'), Decimal('-106.48748')),
#  ('ARRT66G1187FB3DDF9', 'Freddie King', 'Gilmer, TX', None, None),
#  ('ARU5Y6P1187FB5B6A5', 'Gene Watson', 'Palestine, TX', Decimal('31.76170'), Decimal('-95.63200')),
#  ('AR1OM2Q1187FB5186E', 'D Black', 'Houston TX ', Decimal('29.76044'), Decimal('-95.36978')),
#  ('ARB3TCS1187B99A0D2', 'Ornette Coleman', 'Fort Worth, TX', Decimal('32.74862'), Decimal('-97.32925')),
#  ('ARH7WUK1187FB38926', 'Thanassis Moraitis', 'Austin, TX', Decimal('30.26760'), Decimal('-97.74298')),
#  ('ARITORG1187FB3ADA3', 'England Dan & John Ford Coley', 'Austin, TX', Decimal('30.26760'), Decimal('-97.74298')),
#  ('ARKFXJJ1187B9AAB59', 'Sam The Sham & The Pharaohs', 'Dallas, TX', Decimal('32.77814'), Decimal('-96.79540')),
#  ('ARKWI7M1187B9B7713', "Destiny's Child", 'Houston, TX', None, None),
#  ('ARMM25Z1187FB5A8C1', 'Jessy Dixon', 'San Antonio, TX', Decimal('29.42448'), Decimal('-98.49461')),
#  ('ARMUMD81187FB52347', 'Larry Coryell', 'Galveston, TX', Decimal('29.29533'), Decimal('-94.80786')),
#  ('ARNR7GU1187B9B11E7', 'Mutt', 'Dallas, TX', Decimal('32.77814'), Decimal('-96.79540')),
#  ('ARNRA801187FB5587A', 'Eli Young Band', 'Denton, TX', None, None),
#  ('ARRFHHE1187B98FE75', 'Voxtrot', 'Austin, TX', Decimal('30.26760'), Decimal('-97.74298')),
#  ('ARS86AJ1187B9B4225', 'Janis Joplin', 'Port Arthur, TX', None, None),
#  ('ARV7VUX1187B9B8D1C', 'RODNEY CROWELL', 'Houston, TX', None, None),
#  ('ARV7VUX1187B9B8D1C', 'Rodney Crowell;Rosanne Cash', 'Houston, TX', None, None),
#  ('ARWPKS11187FB3EE0D', 'Carrie Rodriguez', 'Austin TX', None, None),
#  ('ARXXCAI1187FB4D555', 'At The Drive-In', 'El Paso, TX', Decimal('31.75916'), Decimal('-106.48748')),
#  ('ARXXCAI1187FB4D555', 'At The Drive In', 'El Paso, TX', Decimal('31.75916'), Decimal('-106.48748')),
#  ('ARZF5231187B9AEF2B', 'Bobbi Humphrey', 'Marlin, TX', Decimal('31.30627'), Decimal('-96.89773')),
#  ('AR11YQ81187FB3C654', 'Dixie Chicks', 'Austin, TX', None, None),
#  ('AR1TLHT1187B991D2E', 'Little Willie Littlefield', 'Houston, TX', Decimal('29.76044'), Decimal('-95.36978')),
#  ('AR4DJG01187FB59EEC', 'Ernestine Anderson', 'Houston, TX', Decimal('29.76044'), Decimal('-95.36978')),
#  ('AR93RTI1187B98ECFB', 'Mance Lipscomb', 'Navasota, TX', Decimal('30.38815'), Decimal('-96.08780')),
#  ('AR9LT7R1187FB4543A', 'Darden Smith', 'Brenham, TX', Decimal('30.16602'), Decimal('-96.39997')),
#  ('ARAHEOM11E2835D52F', 'A3', 'Houston TX', Decimal('31.16890'), Decimal('-100.07715')),
#  ('ARAW99S1187B9B6EBF', 'Phil Ochs', 'El Paso, TX', None, None),
#  ('ARDK0551187FB5AC48', 'Blind Willie Johnson', 'Marlin, TX', Decimal('31.30627'), Decimal('-96.89773')),
#  ('ARE4SXN1187FB38701', 'The Gourds', 'Austin TX', Decimal('30.26760'), Decimal('-97.74298')),
#  ('ARE4SXN1187FB38701', 'Gourds_ The', 'Austin TX', Decimal('30.26760'), Decimal('-97.74298')),
#  ('AREEQPY1187FB5B9E3', 'Miranda Lambert', 'Lindale, TX', None, None),
#  ('ARER3QP1187B9A8DC4', 'Chris Tomlin', 'Grand Saline, TX', None, None),
#  ('ARLIBVA1187B99074B', 'ZZ Top', 'Houston, TX', None, None),
#  ('ARLO5L61187B9B26F4', 'Robert Glasper', 'Houston, TX', Decimal('29.76044'), Decimal('-95.36978')),
#  ('ARMNFB41187B9AD2DC', "Old 97's", 'Dallas, TX', None, None),
#  ('AROUKFV1187FB3CF2B', 'Sound Team', 'Austin, TX', Decimal('30.26760'), Decimal('-97.74298')),
#  ('ARPQ4Z01187FB3A736', 'Butthole Surfers', 'San Antonio, TX', Decimal('29.42448'), Decimal('-98.49461')),
#  ('ARPQ4Z01187FB3A736', 'Butthole Surfers', 'San Antonio, TX', None, None),
#  ('ARRRVMG1187FB532AC', 'Radney Foster', 'Del Rio, TX', Decimal('29.36624'), Decimal('-100.89818')),
#  ('ARUSW6X1187FB3CF6E', 'Bobby Fuller Four', 'El Paso, TX', Decimal('31.75916'), Decimal('-106.48748')),
#  ('ARWXBCL1187FB59873', 'Tosca', 'Austin, TX', Decimal('30.26760'), Decimal('-97.74298')),
#  ('ARYWKWZ1187FB53C75', 'Daron Norwood', 'Lubbock, TX', Decimal('33.59232'), Decimal('-101.85587')),
#  ('AR2R0MS1187B99F6A8', 'Tanya Tucker', 'Seminole, TX', Decimal('32.72661'), Decimal('-102.64505')),
#  ('AR6DZXH1187FB52DD3', 'Clay Walker', 'Beaumont, TX', Decimal('30.08615'), Decimal('-94.10157')),
#  ('AR7S48C1187B99711E', 'Zuzu Bollin', 'Frisco, TX', Decimal('33.15048'), Decimal('-96.83463')),
#  ('ARB2FS51187FB42679', 'Billy Joe Shaver', 'Corsicana, TX', None, None),
#  ('ARCVKG01187B9B3273', 'Flyleaf', 'Belton, TX', None, None),
#  ('ARDQKMM1187FB3F4F0', 'Roky Erickson', 'Dallas, TX', Decimal('32.77814'), Decimal('-96.79540')),
#  ('AREMQN51187B9B7144', 'Chamillionaire', 'Houston, TX', None, None),
#  ('AREMQN51187B9B7144', 'OG Ron C & The Wreckin Yard', 'Houston, TX', None, None),
#  ('ARJLYDW1187FB4236A', 'Leeland', 'Baytown, TX', Decimal('29.72840'), Decimal('-94.99694')),
#  ('ARJT53O1187FB5641F', 'Jana Hunter', 'TX', None, None),
#  ('ARPNTWQ1187B98F09C', 'Mc 900 Ft Jesus', 'Dallas, TX', None, None),
#  ('ARTAUG51187FB3E10D', 'William Daniels;David Vosburgh;Henry Le Clair;Eddie Sauter', 'Fort Worth, TX', Decimal('32.74862'), Decimal('-97.32925')),
#  ('ARTOJHO1187B9B8FF9', 'Perfect Stranger', 'Carthage, TX', Decimal('32.16588'), Decimal('-94.34086')),
#  ('ARW5QWS1187FB57C1B', 'Forever The Sickest Kids', 'Dallas, TX', None, None),
#  ('ARYFXQ21187FB4DAEF', 'Poncho Sanchez', 'Laredo, TX', Decimal('27.53091'), Decimal('-99.50199'))]

# %% [markdown]
# ## Select all the users whos last name is Smith

# %%
# %%sql
# SELECT *
# FROM users
# WHERE last_name LIKE '%Smith%';
# Out:
#  * postgresql://dwhuser:***@dwhcluster.ctkgati4b0qj.us-west-2.redshift.amazonaws.com:5439/dwh
# 3 rows affected.
# [(52, 'Theodore', 'Smith', 'M', 'free'),
#  (92, 'Ryann', 'Smith', 'F', 'free'),
#  (26, 'Ryan', 'Smith', 'M', 'free')]

# %% [markdown]
# ## Select artist whose name is `Radiohead`

# %%
# %%sql
# SELECT *
# FROM artists
# WHERE name LIKE '%Radiohead%';
# Out:
#  * postgresql://dwhuser:***@dwhcluster.ctkgati4b0qj.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [('ARH6W4X1187B99274F', 'Radiohead', 'Oxford, UK', None, None)]

# %% [markdown]
# ## Select all the songs listed from `Radiohead`

# %%
# %%sql
# SELECT
#     *
# FROM
#     songs
#
# WHERE
#     artist_id = 'ARH6W4X1187B99274F'
# Out:
#  * postgresql://dwhuser:***@dwhcluster.ctkgati4b0qj.us-west-2.redshift.amazonaws.com:5439/dwh
# 8 rows affected.
# [('SOPGXXV12AB0183709', 'Bullet Proof ... I Wish I Was (Acoustic)', 'ARH6W4X1187B99274F', 1995, Decimal('214.75219')),
#  ('SOSQIHH12A8C13370B', '15 Step', 'ARH6W4X1187B99274F', 2007, Decimal('237.21751')),
#  ('SOSYMSX12A6310DFE2', 'Subterranean Homesick Alien', 'ARH6W4X1187B99274F', 1997, Decimal('267.20607')),
#  ('SOMLGKF12AB017DF3C', 'Vegetable (Live)', 'ARH6W4X1187B99274F', 1993, Decimal('188.31628')),
#  ('SOBBZPM12AB017DF4B', 'Pop Is Dead', 'ARH6W4X1187B99274F', 1993, Decimal('130.82077')),
#  ('SOUHJKU12AB017DF67', 'Stop Whispering (US Version)', 'ARH6W4X1187B99274F', 1993, Decimal('250.82730')),
#  ('SOUPVWK12A6310EF7A', 'Fast-Track', 'ARH6W4X1187B99274F', 2001, Decimal('197.45913')),
#  ('SOVAHZK12A6310F23C', 'Fake Plastic Trees (Acoustic Version)', 'ARH6W4X1187B99274F', 2009, Decimal('281.12934'))]

# %% [markdown]
# ## Select how many times songs from `Radiohead` have been played

# %%
# %%sql
# SELECT
#     *
# FROM
#     SONGPLAYS
# WHERE
#     artist_id = 'ARH6W4X1187B99274F'
# Out:
#  * postgresql://dwhuser:***@dwhcluster.ctkgati4b0qj.us-west-2.redshift.amazonaws.com:5439/dwh
# 18 rows affected.
# [(445, datetime.datetime(2018, 11, 12, 23, 13, 42, 796000), 80, 'paid', 'SOSQIHH12A8C13370B', 'ARH6W4X1187B99274F', 481, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (973, datetime.datetime(2018, 11, 12, 23, 13, 42, 796000), 80, 'paid', 'SOSQIHH12A8C13370B', 'ARH6W4X1187B99274F', 481, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (1453, datetime.datetime(2018, 11, 12, 23, 13, 42, 796000), 80, 'paid', 'SOSQIHH12A8C13370B', 'ARH6W4X1187B99274F', 481, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (2045, datetime.datetime(2018, 11, 12, 23, 13, 42, 796000), 80, 'paid', 'SOSQIHH12A8C13370B', 'ARH6W4X1187B99274F', 481, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (2181, datetime.datetime(2018, 11, 12, 23, 13, 42, 796000), 80, 'paid', 'SOSQIHH12A8C13370B', 'ARH6W4X1187B99274F', 481, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (3109, datetime.datetime(2018, 11, 12, 23, 13, 42, 796000), 80, 'paid', 'SOSQIHH12A8C13370B', 'ARH6W4X1187B99274F', 481, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (150, datetime.datetime(2018, 11, 2, 18, 36, 53, 796000), 71, 'free', 'SOBBZPM12AB017DF4B', 'ARH6W4X1187B99274F', 70, 'Columbia, SC', '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_1 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D201 Safari/9537.53"'),
#  (462, datetime.datetime(2018, 11, 2, 18, 36, 53, 796000), 71, 'free', 'SOBBZPM12AB017DF4B', 'ARH6W4X1187B99274F', 70, 'Columbia, SC', '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_1 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D201 Safari/9537.53"'),
#  (822, datetime.datetime(2018, 11, 2, 18, 36, 53, 796000), 71, 'free', 'SOBBZPM12AB017DF4B', 'ARH6W4X1187B99274F', 70, 'Columbia, SC', '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_1 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D201 Safari/9537.53"'),
#  (886, datetime.datetime(2018, 11, 2, 18, 36, 53, 796000), 71, 'free', 'SOBBZPM12AB017DF4B', 'ARH6W4X1187B99274F', 70, 'Columbia, SC', '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_1 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D201 Safari/9537.53"'),
#  (1398, datetime.datetime(2018, 11, 2, 18, 36, 53, 796000), 71, 'free', 'SOBBZPM12AB017DF4B', 'ARH6W4X1187B99274F', 70, 'Columbia, SC', '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_1 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D201 Safari/9537.53"'),
#  (1566, datetime.datetime(2018, 11, 2, 18, 36, 53, 796000), 71, 'free', 'SOBBZPM12AB017DF4B', 'ARH6W4X1187B99274F', 70, 'Columbia, SC', '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_1 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D201 Safari/9537.53"'),
#  (127, datetime.datetime(2018, 11, 21, 21, 17, 19, 796000), 49, 'paid', 'SOSYMSX12A6310DFE2', 'ARH6W4X1187B99274F', 816, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (463, datetime.datetime(2018, 11, 21, 21, 17, 19, 796000), 49, 'paid', 'SOSYMSX12A6310DFE2', 'ARH6W4X1187B99274F', 816, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (1079, datetime.datetime(2018, 11, 21, 21, 17, 19, 796000), 49, 'paid', 'SOSYMSX12A6310DFE2', 'ARH6W4X1187B99274F', 816, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (1223, datetime.datetime(2018, 11, 21, 21, 17, 19, 796000), 49, 'paid', 'SOSYMSX12A6310DFE2', 'ARH6W4X1187B99274F', 816, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (1719, datetime.datetime(2018, 11, 21, 21, 17, 19, 796000), 49, 'paid', 'SOSYMSX12A6310DFE2', 'ARH6W4X1187B99274F', 816, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (1863, datetime.datetime(2018, 11, 21, 21, 17, 19, 796000), 49, 'paid', 'SOSYMSX12A6310DFE2', 'ARH6W4X1187B99274F', 816, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0')]
